# %%
import pandas as pd
env_policies = pd.read_csv("..\Datasets\ENVIROMENTAL_POLICY.csv")
env_policies = env_policies.round(2)
env_policies
# Out:
#        COU       Country           VAR                      Variable   YEA  \
# 0      GRC        Greece  ELV_DIESELSO  Emission limit value sulphur  1990
# 1      GRC        Greece  ELV_DIESELSO  Emission limit value sulphur  1991
# 2      GRC        Greece  ELV_DIESELSO  Emission limit value sulphur  1992
# 3      GRC        Greece  ELV_DIESELSO  Emission limit value sulphur  1993
# 4      GRC        Greece  ELV_DIESELSO  Emission limit value sulphur  1994
# ...    ...           ...           ...                           ...   ...
# 17386  ZAF  South Africa       TECHSUP   Technology support policies  2016
# 17387  ZAF  South Africa       TECHSUP   Technology support policies  2017
# 17388  ZAF  South Africa       TECHSUP   Technology support policies  2018
# 17389  ZAF  South Africa       TECHSUP   Technology support policies  2019
# 17390  ZAF  South Africa       TECHSUP   Technology support policies  2020
#
# ...

# %%
list(env_policies['Value'].unique())
# Out:
# [1.0,
#  5.0,
#  6.0,
#  2.0,
#  0.0,
#  3.0,
#  4.0,
#  0.89,
#  0.94,
#  1.11,
#  1.28,
#  1.56,
#  1.61,
#  2.47,
#  2.58,
#  2.64,
#  2.31,
#  2.67,
#  2.56,
#  2.94,
#  3.06,
#  2.83,
#  2.89,
#  3.22,
#  3.44,
#  0.67,
#  0.83,
#  1.17,
#  1.33,
#  1.5,
#  2.14,
#  2.42,
#  2.25,
#  3.36,
#  3.33,
#  3.75,
#  3.86,
#  3.47,
#  3.53,
#  3.61,
#  1.58,
#  1.64,
#  1.75,
#  1.94,
#  2.11,
#  2.61,
#  2.69,
#  2.75,
#  3.03,
#  2.97,
#  3.11,
#  3.42,
#  4.06,
#  3.83,
#  3.72,
#  3.94,
#  3.89,
#  3.78,
#  0.25,
#  2.5,
#  4.75,
#  5.5,
#  1.44,
#  1.39,
#  1.47,
#  1.67,
#  2.08,
#  2.86,
#  3.08,
#  3.25,
#  3.69,
#  3.92,
#  4.22,
#  4.03,
#  4.17,
#  4.56,
#  4.72,
#  4.89,
#  0.5,
#  0.17,
#  0.33,
#  4.5,
#  1.83,
#  2.17,
#  2.33,
#  3.5,
#  3.67,
#  3.17,
#  0.58,
#  0.53,
#  0.64,
#  0.75,
#  0.81,
#  1.14,
#  2.36,
#  2.78,
#  2.72,
#  2.28,
#  2.53,
#  3.56,
#  3.64,
#  4.14,
#  4.42,
#  0.36,
#  0.47,
#  1.19,
#  1.42,
#  1.78,
#  1.89,
#  1.97,
#  2.44,
#  0.69,
# ...

# %%
env_policies['Country'].unique()
# Out:
# array(['Greece', 'Portugal', 'France', 'Belgium', 'Switzerland',
#        'Czechia', 'Japan', 'Denmark', 'Italy', 'Spain', 'Sweden',
#        'United Kingdom', 'Poland', 'United States', 'Netherlands',
#        'Ireland', 'Finland', 'Canada', 'Hungary', 'Australia', 'Germany',
#        'Norway', 'Slovak Republic', 'Korea', 'Austria', 'Türkiye',
#        'Slovenia', 'South Africa', "China (People's Republic of)",
#        'Indonesia', 'Brazil', 'Russia', 'India'], dtype=object)

# %%
env_policies_gral = env_policies[env_policies['Year'] == 2020].copy()
env_policies_gral = env_policies_gral[env_policies_gral['Variable'].isin(['Environmental Policy Stringency'])].copy()
columns_to_drop = ['Variable', 'Year','COU', 'VAR', 'YEA', 'Unit Code', 'Unit', 'PowerCode Code', 'PowerCode', 'Reference Period Code', 'Reference Period', 'Flag Codes', 'Flags']
env_policies_gral.drop(columns=columns_to_drop, inplace=True)
country_names = {
    'Czechia': 'Czech Republic',
    'Slovak Republic':'Slovakia',
    'Türkiye': 'Turkey',
    "China (People's Republic of)": 'China'
}
env_policies_gral["Country"].replace(country_names, inplace=True)
env_policies_gral
# Out:
#               Country  Value
# 123           Belgium   3.44
# 464    United Kingdom   3.61
# 557             Japan   3.78
# 805            France   4.89
# 1890           Poland   3.47
# 2634      Switzerland   4.50
# 2820           Greece   2.89
# 3285           Sweden   3.83
# 4153            Italy   3.72
# 5052      Netherlands   3.47
# 5145   Czech Republic   2.94
# 5610          Finland   4.11
# 5796         Slovakia   2.50
# 6137         Portugal   2.78
# 6602          Germany   3.47
# 6788           Turkey   2.89
# 7625            Korea   3.17
# 7718          Austria   3.31
# 8400           Norway   3.94
# 8803           Canada   3.03
# 9144          Denmark   3.72
# 10074         Hungary   2.81
# 10477         Ireland   3.00
# 11035           Spain   2.50
# 11562       Australia   2.92
# 11872   United States   3.03
# 12151    South Africa   0.92
# 12461           China   3.14
# 12554          Brazil   0.89
# 12926          Russia   1.17
# 12988        Slovenia   3.22
# ...

# %%
env_policies.to_csv(r"..\CSV\env_policies.csv", index=False)

# %%
selected_policy = env_policies.loc[env_policies['Country'].isin(['Spain', 'Australia'])].copy()
selected_policy = selected_policy[selected_policy['Year'] > 2010].copy()
selected_policy = selected_policy[selected_policy['Variable'].isin(['Environmental Policy Stringency'])].copy()
columns_to_drop = ['Variable','COU', 'VAR', 'YEA', 'Unit Code', 'Unit', 'PowerCode Code', 'PowerCode', 'Reference Period Code', 'Reference Period', 'Flag Codes', 'Flags']
selected_policy.drop(columns=columns_to_drop, inplace=True)
selected_policy
# Out:
#          Country  Year  Value
# 11026      Spain  2011   2.83
# 11027      Spain  2012   2.81
# 11028      Spain  2013   2.22
# 11029      Spain  2014   2.39
# 11030      Spain  2015   2.39
# 11031      Spain  2016   2.28
# 11032      Spain  2017   2.28
# 11033      Spain  2018   2.44
# 11034      Spain  2019   2.44
# 11035      Spain  2020   2.50
# 11553  Australia  2011   3.00
# 11554  Australia  2012   3.42
# 11555  Australia  2013   3.53
# 11556  Australia  2014   2.69
# 11557  Australia  2015   2.69
# 11558  Australia  2016   2.69
# 11559  Australia  2017   2.75
# 11560  Australia  2018   2.86
# 11561  Australia  2019   2.86
# 11562  Australia  2020   2.92

# %%
selected_policy_df_ = selected_policy.transpose()
selected_policy_df_
# Out:
#          11026  11027  11028  11029  11030  11031  11032  11033  11034  11035  \
# Country  Spain  Spain  Spain  Spain  Spain  Spain  Spain  Spain  Spain  Spain
# Year      2011   2012   2013   2014   2015   2016   2017   2018   2019   2020
# Value     2.83   2.81   2.22   2.39   2.39   2.28   2.28   2.44   2.44    2.5
#
#              11553      11554      11555      11556      11557      11558  \
# Country  Australia  Australia  Australia  Australia  Australia  Australia
# Year          2011       2012       2013       2014       2015       2016
# Value          3.0       3.42       3.53       2.69       2.69       2.69
#
#              11559      11560      11561      11562
# Country  Australia  Australia  Australia  Australia
# Year          2017       2018       2019       2020
# Value         2.75       2.86       2.86       2.92

# %%
selected_policy_df_.reset_index(drop=True, inplace=True)
selected_policy_df_
# Out:
#    11026  11027  11028  11029  11030  11031  11032  11033  11034  11035  \
# 0  Spain  Spain  Spain  Spain  Spain  Spain  Spain  Spain  Spain  Spain
# 1   2011   2012   2013   2014   2015   2016   2017   2018   2019   2020
# 2   2.83   2.81   2.22   2.39   2.39   2.28   2.28   2.44   2.44    2.5
#
#        11553      11554      11555      11556      11557      11558  \
# 0  Australia  Australia  Australia  Australia  Australia  Australia
# 1       2011       2012       2013       2014       2015       2016
# 2        3.0       3.42       3.53       2.69       2.69       2.69
#
#        11559      11560      11561      11562
# 0  Australia  Australia  Australia  Australia
# 1       2017       2018       2019       2020
# 2       2.75       2.86       2.86       2.92

# %%
rows_to_delete = [0]
selected_policy_df_.drop(rows_to_delete, inplace=True)
selected_policy_df_
# Out:
#   11026 11027 11028 11029 11030 11031 11032 11033 11034 11035 11553 11554  \
# 1  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020  2011  2012
# 2  2.83  2.81  2.22  2.39  2.39  2.28  2.28  2.44  2.44   2.5   3.0  3.42
#
#   11555 11556 11557 11558 11559 11560 11561 11562
# 1  2013  2014  2015  2016  2017  2018  2019  2020
# 2  3.53  2.69  2.69  2.69  2.75  2.86  2.86  2.92

# %%
selected_policy_df_.columns = selected_policy_df_.iloc[0]
selected_policy_df_
# Out:
# 1  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020  2011  2012  \
# 1  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020  2011  2012
# 2  2.83  2.81  2.22  2.39  2.39  2.28  2.28  2.44  2.44   2.5   3.0  3.42
#
# 1  2013  2014  2015  2016  2017  2018  2019  2020
# 1  2013  2014  2015  2016  2017  2018  2019  2020
# 2  3.53  2.69  2.69  2.69  2.75  2.86  2.86  2.92

# %%
selected_policy_df_= selected_policy_df_.iloc[1:]
selected_policy_df_
# Out:
# 1  2011  2012  2013  2014  2015  2016  2017  2018  2019 2020 2011  2012  2013  \
# 2  2.83  2.81  2.22  2.39  2.39  2.28  2.28  2.44  2.44  2.5  3.0  3.42  3.53
#
# 1  2014  2015  2016  2017  2018  2019  2020
# 2  2.69  2.69  2.69  2.75  2.86  2.86  2.92

# %%
def new_df_country(country):
    selected_policy_df = selected_policy[selected_policy['Country'] == country].copy()
    selected_policy_df_ = selected_policy_df.transpose()
    selected_policy_df_.reset_index(drop=True, inplace=True)
    rows_to_delete = [0]
    selected_policy_df_.drop(rows_to_delete, inplace=True)
    selected_policy_df_.columns = selected_policy_df_.iloc[0]
    selected_policy_df_= selected_policy_df_.iloc[1:]
    return selected_policy_df_

# %%
df_Spain = new_df_country('Spain')
df_Spain
# Out:
# 1  2011  2012  2013  2014  2015  2016  2017  2018  2019 2020
# 2  2.83  2.81  2.22  2.39  2.39  2.28  2.28  2.44  2.44  2.5

# %%
df_Australia = new_df_country('Australia')
df_Australia
# Out:
# 1 2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# 2  3.0  3.42  3.53  2.69  2.69  2.69  2.75  2.86  2.86  2.92

# %%
result_df = pd.concat([df_Australia, df_Spain], ignore_index=True)
result_df
# Out:
# 1  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# 0   3.0  3.42  3.53  2.69  2.69  2.69  2.75  2.86  2.86  2.92
# 1  2.83  2.81  2.22  2.39  2.39  2.28  2.28  2.44  2.44   2.5

# %%
result_df['Country'] = ['Australia', 'Spain']
result_df
# Out:
# 1  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020    Country
# 0   3.0  3.42  3.53  2.69  2.69  2.69  2.75  2.86  2.86  2.92  Australia
# 1  2.83  2.81  2.22  2.39  2.39  2.28  2.28  2.44  2.44   2.5      Spain

# %%
result_df.reset_index(drop=True, inplace=True)
result_df.set_index('Country', inplace=True)

# %%
result_df
# Out:
# 1          2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# Country
# Australia   3.0  3.42  3.53  2.69  2.69  2.69  2.75  2.86  2.86  2.92
# Spain      2.83  2.81  2.22  2.39  2.39  2.28  2.28  2.44  2.44   2.5

# %%
result_df.columns.name = None

# %%
result_df.reset_index(inplace=True)

# %%
result_df
# Out:
#      Country  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# 0  Australia   3.0  3.42  3.53  2.69  2.69  2.69  2.75  2.86  2.86  2.92
# 1      Spain  2.83  2.81  2.22  2.39  2.39  2.28  2.28  2.44  2.44   2.5

# %%
numeric_cols = result_df.columns[1:]
new_row = result_df[numeric_cols].iloc[0] - result_df[numeric_cols].iloc[1]
result_df.loc[result_df.index[-1] + 1] = result_df.iloc[-1].copy()
result_df.loc[result_df.index[-1], numeric_cols] = new_row.values
result_df
# Out:
#      Country  2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# 0  Australia   3.0  3.42  3.53  2.69  2.69  2.69  2.75  2.86  2.86  2.92
# 1      Spain  2.83  2.81  2.22  2.39  2.39  2.28  2.28  2.44  2.44   2.5
# 2      Spain  0.17  0.61  1.31   0.3   0.3  0.41  0.47  0.42  0.42  0.42

# %%
numeric_cols = result_df.columns[1:]
new_row = (result_df[numeric_cols].iloc[2] / result_df[numeric_cols].iloc[1])*100
result_df.loc[result_df.index[-1] + 1] = result_df.iloc[-1].copy()
result_df.loc[result_df.index[-1], numeric_cols] = new_row.values
result_df
# Out:
#      Country      2011       2012       2013       2014       2015       2016  \
# 0  Australia       3.0       3.42       3.53       2.69       2.69       2.69
# 1      Spain      2.83       2.81       2.22       2.39       2.39       2.28
# 2      Spain      0.17       0.61       1.31        0.3        0.3       0.41
# 3      Spain  6.007067  21.708185  59.009009  12.552301  12.552301  17.982456
#
#         2017       2018       2019  2020
# 0       2.75       2.86       2.86  2.92
# 1       2.28       2.44       2.44   2.5
# 2       0.47       0.42       0.42  0.42
# 3  20.614035  17.213115  17.213115  16.8

# %%
result_df.loc[2, 'Country'] = 'Difference'
result_df.loc[3, 'Country'] = 'Difference in %'
result_df
# Out:
#            Country      2011       2012       2013       2014       2015  \
# 0        Australia       3.0       3.42       3.53       2.69       2.69
# 1            Spain      2.83       2.81       2.22       2.39       2.39
# 2       Difference      0.17       0.61       1.31        0.3        0.3
# 3  Difference in %  6.007067  21.708185  59.009009  12.552301  12.552301
#
#         2016       2017       2018       2019  2020
# 0       2.69       2.75       2.86       2.86  2.92
# 1       2.28       2.28       2.44       2.44   2.5
# 2       0.41       0.47       0.42       0.42  0.42
# 3  17.982456  20.614035  17.213115  17.213115  16.8

# %%
result_df.iloc[3, 1:] = pd.to_numeric(result_df.iloc[3, 1:], errors='coerce').round(2)

# %%
result_df
# Out:
#            Country  2011   2012   2013   2014   2015   2016   2017   2018  \
# 0        Australia   3.0   3.42   3.53   2.69   2.69   2.69   2.75   2.86
# 1            Spain  2.83   2.81   2.22   2.39   2.39   2.28   2.28   2.44
# 2       Difference  0.17   0.61   1.31    0.3    0.3   0.41   0.47   0.42
# 3  Difference in %  6.01  21.71  59.01  12.55  12.55  17.98  20.61  17.21
#
#     2019  2020
# 0   2.86  2.92
# 1   2.44   2.5
# 2   0.42  0.42
# 3  17.21  16.8
