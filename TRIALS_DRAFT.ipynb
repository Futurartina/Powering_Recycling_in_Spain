# %%
import pandas as pd

# %%
desc_1 = pd.read_csv("C:\\Users\\marti\\OneDrive\\materials-2022-07-27.csv")

# %%
desc_1
# Out:
#     Id                                 Name  \
# 0   18                        Reutilización
# 1   17  Productos con materiales reciclados
# 2   16                           Reparación
# 3   15                          Envase cero
# 4   14                  Residuos Especiales
# 5   13                               Caucho
# 6   12                      Donar o regalar
# 7   11                     Aceite de cocina
# 8   10                 Residuos voluminosos
# 9    9                Residuos electrónicos
# 10   8                  Residuos peligrosos
# 11   7                Residuos compostables
# 12   6               Materiales reciclables
# 13   5                   Residuos mezclados
# 14   4                              Vidrios
# 15   3                            Plásticos
# 16   2                       Papel y cartón
# 17   1                              Metales
#
#                                           Information  \
# 0                                                 NaN
# ...

# %%
desc = pd.read_csv("C:\\Users\\marti\\OneDrive\\containers-2022-07-27.csv")

# %%
desc
# Out:
#          Id  External   Latitude  Longitude  \
# 0     11780       NaN -34.753762 -55.845820
# 1     11779       NaN -34.592136 -54.124148
# 2     11778       NaN -34.618292 -54.151271
# 3     11777       NaN -34.640561 -54.159035
# 4     11776       NaN -34.658430 -54.158926
# ...     ...       ...        ...        ...
# 2418   1510       5.0 -30.402230 -56.465383
# 2419   1509       4.0 -32.421398 -57.390998
# 2420   1508       3.0 -34.202866 -54.764817
# 2421   1507       2.0 -34.193716 -56.339062
# 2422   1506       1.0 -34.412437 -56.400967
#
#                                                    Site  \
# 0                                                   NaN
# 1     Club de La Pedrera (martes previa coordinación...
# 2     Placita de Arachania (sábados previa coordinac...
# 3     Club Deportivo y Social La Aguada (previa coor...
# 4                                Municipio de La Paloma
# ...                                                 ...
# ...

# %%
wast = pd.read_csv("C:\\Users\\marti\\OneDrive\\wastes-2022-07-27.csv")

# %%
wast
# Out:
#       Id                                             Nombre  \
# 0    264                                       Ecoladrillos
# 1    263  Bolsas o envoltorios de grandes electrodomésticos
# 2    262                Bolsa de nylon de colchón o sommier
# 3    261                               Bicicletas (reparar)
# 4    260                               Envases compostables
# ..   ...                                                ...
# 258    5                                              Lonas
# 259    4                                              Ollas
# 260    3                                       Papel afiche
# 261    2                Perchas de madera, metal o plástico
# 262    1                                        Computadora
#
#                                             Deposition  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# ...

# %%
wast_3 = pd.read_csv("C:\\Users\\marti\\OneDrive\\BCN.csv")
wast_3
# Out:
#         Any  Codi municipi               Municipi                Comarca  \
# 0      2000       430017.0            Aiguamúrcia               Alt Camp
# 1      2000       430056.0                Alcover               Alt Camp
# 2      2000       430108.0                   Alió               Alt Camp
# 3      2000       430347.0                 Bràfim               Alt Camp
# 4      2000       430363.0         Cabra del Camp               Alt Camp
# ...     ...            ...                    ...                    ...
# 21786  2022       431779.0                Vinebre          Ribera d'Ebre
# 21787  2022       431785.0     Vinyols i els Arcs              Baix Camp
# 21788  2022        83089.0      Viver i Serrateix               Berguedà
# 21789  2022       430521.0                  Xerta              Baix Ebre
# 21790  2022            NaN  No territorialitzable  No territorialitzable
#
#        Població  Autocompostatge  Matèria orgànica  Poda i jardineria  \
# ...

# %%
wast_3 = pd.read_csv("C:\\Users\\marti\\OneDrive\\AUS.csv")
wast_3
# Out:
#            Year Jurisdiction                                  Category  \
# 0     2020-2021          ACT                                 Biosolids
# 1     2020-2021          ACT                                 Biosolids
# 2     2020-2021          ACT         Building and demolition materials
# 3     2020-2021          ACT         Building and demolition materials
# 4     2020-2021          ACT         Building and demolition materials
# ...         ...          ...                                       ...
# 3273  2006-2007           WA  Textiles, leather & rubber (excl. tyres)
# 3274  2006-2007           WA                    Unclassified materials
# 3275  2006-2007           WA                    Unclassified materials
# 3276  2006-2007           WA                    Unclassified materials
# 3277  2006-2007           WA                    Unclassified materials
#
#                       Management             Fate         Tonnes  \
# ...

# %%
wast_3['Category'].value_counts()
# Out:
# Category
# Hazardous wastes                            672
# Organics                                    400
# Paper & cardboard                           384
# Textiles, leather & rubber (excl. tyres)    381
# Unclassified materials                      325
# Plastics                                    217
# Building and demolition materials           197
# Metals                                      193
# Biosolids                                   192
# Glass                                       192
# Ash                                         125
# Name: count, dtype: int64

# %%
import pandas as pd

# %%
wast_4 = pd.read_csv("C:\\Users\\marti\\OneDrive\\Survey.csv")
wast_4
# Out:
#    Do you consider your effect on the environment as a consumer before purchasing general day to day products?  \
# 0                                                 Yes
# 1                                                  No
# 2                                           Sometimes
# 3                                           Sometimes
# 4                                           Sometimes
# ..                                                ...
# 68                                                 No
# 69                                                 No
# 70                                          Sometimes
# 71                                                Yes
# 72                                                 No
#
#    Do you actively seek out information on how sustainable products are made?  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                  No
# ...

# %%
wast_10 = pd.read_csv("C:\\Users\\marti\\OneDrive\\1.csv")
wast_10
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 wast_10 = pd.read_csv("C:\\Users\\marti\\OneDrive\\1.csv")
#       2 wast_10
#
# File ~\miniconda3\envs\ironhack\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
wast_6 = pd.read_csv("C:\\Users\\marti\\OneDrive\\2.csv")
wast_6
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
wast_7 = pd.read_csv("C:\\Users\\marti\\OneDrive\\3.csv")
wast_7
# Out:
#       INDICATOR_CODE                                     INDICATOR_NAME  \
# 0  SE.ADT.1524.LT.ZS  Literacy rate, youth total (% of people ages 1...
#
#                                          SOURCE_NOTE  \
# 0  Youth literacy rate is the percentage of peopl...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  UNESCO Institute for Statistics (UIS). UIS.Sta...         NaN

# %%
load_dotenv()
token = os.getenv("token")

# %%
def requests_for_foursquare (query, lat, lon):
    
    url = 'https://api.foursquare.com/v3/places/search?query=coffee&ll=II%3D-27.0000000%2C%20133.0000000'
    
    headers = {
        "accept": "application/json",
        "Authorization": token
        }  
    response = requests.get(url, headers=headers)
        
           
    try:
        return requests.get(url, headers=headers).json()
    except:
        print("no :(")
   
# Defines a function to extract info from 4square.

# %%
res = requests_for_foursquare ("coffee", -27.0000000, 133.0000000)
res
# Out:
# {'message': 'Invalid request token.'}

# %%
def transform_request_into_df (res):
    list_of_dictionaries = [extracting_from_one_element (element) for element in res["results"]]
    return pd.DataFrame(list_of_dictionaries)

# %%
list_of_dictionaries = [extracting_from_one_element (element) for element in res["results"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 list_of_dictionaries = [extracting_from_one_element (element) for element in res["results"]]
#
# KeyError: 'results'

# %%
df = pd.DataFrame(list_of_dictionaries)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df = pd.DataFrame(list_of_dictionaries)
#       2 df
#
# NameError: name 'list_of_dictionaries' is not defined
